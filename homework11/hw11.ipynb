# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my
#understanding of the material
# Sarah Jauregui

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Your code here (WITHOUT NUMPY! or any other modules/libraries/packages)

def orbital_period(a):
    #This function calculates orbital period (T) based on a given semi-major axis value (a)
    T=((a**3)**0.5)
    return T

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
# Your code here

print(orbital_period(a=0.5))
print(orbital_period(a=1))
print(orbital_period(a=1.5))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
# Your code here
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Your comment (2 sentences)
#you can call numpy once in a notebook and as long as you call the cell, numpy will work throughout the entire notebook

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
# Your code here
def orbital_period_numpy(a):
    #This function calculates orbital period (T) based on a given semi-major axis value (a)
    period=np.sqrt(a**3)
    return period
print(orbital_period_numpy(a=0.5))
# Out:
# 0.3535533905932738

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
# Your code here
print(orbital_period(a=5))
print(orbital_period_numpy(a=5))
# Out:
# 11.180339887498949
# 11.180339887498949

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your comment here
#Honestly, both of the functions finished running instantaneously. But I know that numpy is supposed to make functions run faster when dealing
#with numerical calculations.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1000 semi-major axis values.

# %%
# Your code here
semi_major_list=np.linspace(0.1,100,1000000)
semi_major=np.array(semi_major_list)
#print(semi_major[:10])

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
# Your code here
functions=[orbital_period,orbital_period_numpy]
for function in functions:
    t_0=time.perf_counter()
    timed_results=function(semi_major)
    t_f=time.perf_counter()
    times=t_f-t_0
    print(f"Time for {function.__name__}: {times:.12f} seconds\n")
# Out:
# Time for orbital_period: 0.035860900010 seconds
#
# Time for orbital_period_numpy: 0.033807300031 seconds

# %% [raw]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your code here
#The second function, that uses numpy, ran faster. Numpy is better at numerical calculations
#and executes them faster.

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
for i in range(len(temperatures)):
    if temperatures[i]<350:
        print(radii[i])
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Your code here
three_radii=radii[:3]
print(three_radii)
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
# Your code here
data_dict=dict(zip(radii,temperatures))
print(data_dict)
# Out:
# {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500, 0.6: 450}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Your code here
names=['Megan Planet','Mia Planet','Christian Planet','Alper Planet','Ashley Planet','Lisa Planet']
planet_dict_named={}
for i in range(len(radii)):
    planet_dict_named[names[i]]={'radius':radii[i],'temperature':temperatures[i]}
print(planet_dict_named)
# Out:
# {'Megan Planet': {'radius': 1.2, 'temperature': 300}, 'Mia Planet': {'radius': 0.8, 'temperature': 400}, 'Christian Planet': {'radius': 1.5, 'temperature': 350}, 'Alper Planet': {'radius': 2.0, 'temperature': 280}, 'Ashley Planet': {'radius': 1.0, 'temperature': 500}, 'Lisa Planet': {'radius': 0.6, 'temperature': 450}}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Your code here
new_dict={}

for i in range(len(radii)):
    if 1<=radii[i]<=2:
        new_dict[names[i]]={'radius': radii[i], 'temperature': temperatures[i]}
print(new_dict)
# Out:
# {'Megan Planet': {'radius': 1.2, 'temperature': 300}, 'Christian Planet': {'radius': 1.5, 'temperature': 350}, 'Alper Planet': {'radius': 2.0, 'temperature': 280}, 'Ashley Planet': {'radius': 1.0, 'temperature': 500}}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
# Your code here
semi_major=np.array(semi_major_list)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
# Your code here
mean=np.mean(semi_major)
print(mean)

med=np.median(semi_major)
print(med)

min=np.min(semi_major)
print(min)

max=np.max(semi_major)
print(max)
# Out:
# 50.04999999999999
# 50.05
# 0.1
# 100.0

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
# Your code here
std=np.std(semi_major)
print(std)
#This function calculates the standard deviation of semi_major
# Out:
# 28.83867478468217

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Your code here
planet_data_twoD=np.array([radii,temperatures])
print(planet_data_twoD)
# Out:
# [[  1.2   0.8   1.5   2.    1.    0.6]
#  [300.  400.  350.  280.  500.  450. ]]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
# Your code here
row_number=0
for row in planet_data_twoD:
    if row_number==1:
        print(row[2])
    row_number +=1
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# Your code here
val=planet_data_twoD[1,2]
print(val)
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# Your code here
import matplotlib.pyplot as plt

semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
#print(orbital_period(a=0.8))
orbital_periods=[0.3535,1,2.828,1.837,1.314,0.715]

plt.scatter(semi_major_axes,orbital_periods)
plt.xlabel('Semi Major Axes')
plt.ylabel('Orbital Periods')
plt.title('Orbital Periods of Exoplanets')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
# Your code here
plt.bar(radii,temperatures)
plt.xlabel('Radii')
plt.ylabel('Equilibrium Temperatures')
plt.title('Equilibrium Temperatures vs. Radii')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
# Your code here
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(semi_major_axes,orbital_periods)
plt.xlabel('Semi Major Axes')
plt.ylabel('Orbital Periods')
plt.title('Orbital Periods of Exoplanets')
plt.legend()

plt.subplot(1,2,2)
plt.bar(radii,temperatures)
plt.xlabel('Radii')
plt.ylabel('Equilibrium Temperatures')
plt.title('Equilibrium Temperatures vs. Radii')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
# Your code here
from orbital_period_calculation import orbital_period 
print(orbital_period(a=4))
# Out:
# 8.0
